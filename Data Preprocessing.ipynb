# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading Dataset

# %%
#loading or exporting csv file by using pandas library
df=pd.read_csv("All India Consumer Price Index (Rural Vs Urban) upto May 2023.csv")
df
# Out:
#           Sector  Year     Month  Cereals and products  Meat and fish    Egg  \
# 0          Rural  2013   January                 107.5          106.3  108.1
# 1          Urban  2013   January                 110.5          109.1  113.0
# 2    Rural+Urban  2013   January                 108.4          107.3  110.0
# 3          Rural  2013  February                 109.2          108.7  110.2
# 4          Urban  2013  February                 112.9          112.9  116.9
# ..           ...   ...       ...                   ...            ...    ...
# 366        Rural  2023     April                 173.3          206.9  167.9
# 367        Urban  2023     April                 174.8          213.7  172.4
# 368  Rural+Urban  2023     April                 173.8          209.3  169.6
# 369        Rural  2023       May                 173.2          211.5  171.0
# 370        Urban  2023       May                 174.7          219.4  176.7
#
# ...

# %% [markdown]
# Performinng Data Preprocessing

# %%
#shows given numbers of rows data from dataset
df.head(20)
# Out:
#          Sector  Year     Month  Cereals and products  Meat and fish    Egg  \
# 0         Rural  2013   January                 107.5          106.3  108.1
# 1         Urban  2013   January                 110.5          109.1  113.0
# 2   Rural+Urban  2013   January                 108.4          107.3  110.0
# 3         Rural  2013  February                 109.2          108.7  110.2
# 4         Urban  2013  February                 112.9          112.9  116.9
# 5   Rural+Urban  2013  February                 110.4          110.2  112.8
# 6         Rural  2013     March                 110.2          108.8  109.9
# 7         Urban  2013     March                 113.9          111.4  113.2
# 8   Rural+Urban  2013     March                 111.4          109.7  111.2
# 9         Rural  2013     April                 110.2          109.5  106.9
# 10        Urban  2013     April                 114.6          113.4  106.0
# ...

# %%
#gives number of rows and columns in dataset
df.shape
# Out:
# (371, 30)

# %%
#information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371 entries, 0 to 370
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Sector                               371 non-null    object
#  1   Year                                 371 non-null    int64
#  2   Month                                371 non-null    object
#  3   Cereals and products                 368 non-null    float64
#  4   Meat and fish                        365 non-null    float64
#  5   Egg                                  368 non-null    float64
#  6   Milk and products                    368 non-null    float64
#  7   Oils and fats                        368 non-null    float64
#  8   Fruits                               368 non-null    float64
#  9   Vegetables                           368 non-null    float64
#  10  Pulses and products                  368 non-null    float64
# ...

# %%
#finding null values and show output in boolean values(True or False)
df.isnull()
# Out:
#      Sector   Year  Month  Cereals and products  Meat and fish    Egg  \
# 0     False  False  False                 False          False  False
# 1     False  False  False                 False          False  False
# 2     False  False  False                 False          False  False
# 3     False  False  False                 False          False  False
# 4     False  False  False                 False          False  False
# ..      ...    ...    ...                   ...            ...    ...
# 366   False  False  False                 False          False  False
# 367   False  False  False                 False          False  False
# 368   False  False  False                 False          False  False
# 369   False  False  False                 False          False  False
# 370   False  False  False                 False          False  False
#
#      Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# ...

# %%
#sum of null values from dataset
df.isnull().sum()
# Out:
# Sector                                   0
# Year                                     0
# Month                                    0
# Cereals and products                     3
# Meat and fish                            6
# Egg                                      3
# Milk and products                        3
# Oils and fats                            3
# Fruits                                   3
# Vegetables                               3
# Pulses and products                      3
# Sugar and Confectionery                  3
# Spices                                   3
# Non-alcoholic beverages                  3
# Prepared meals, snacks, sweets etc.      6
# Food and beverages                       3
# Pan, tobacco and intoxicants             6
# Clothing                                 6
# Footwear                                 6
# Clothing and footwear                    6
# Housing                                122
# Fuel and light                           3
# ...

# %%
#shows the null values from particular column in boolean data type
A=pd.isnull(df["Fuel and light"])
A
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 366    False
# 367    False
# 368    False
# 369    False
# 370    False
# Name: Fuel and light, Length: 371, dtype: bool

# %%
#shows not null values in dataset as true is value is not null and false if value is null (opposite the result of isnull)
df.notnull()
# Out:
#      Sector  Year  Month  Cereals and products  Meat and fish   Egg  \
# 0      True  True   True                  True           True  True
# 1      True  True   True                  True           True  True
# 2      True  True   True                  True           True  True
# 3      True  True   True                  True           True  True
# 4      True  True   True                  True           True  True
# ..      ...   ...    ...                   ...            ...   ...
# 366    True  True   True                  True           True  True
# 367    True  True   True                  True           True  True
# 368    True  True   True                  True           True  True
# 369    True  True   True                  True           True  True
# 370    True  True   True                  True           True  True
#
#      Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# 0                 True           True    True        True  ...    False
# ...

# %%
#sum of not null values in each column
df.notnull().sum()
# Out:
# Sector                                 371
# Year                                   371
# Month                                  371
# Cereals and products                   368
# Meat and fish                          365
# Egg                                    368
# Milk and products                      368
# Oils and fats                          368
# Fruits                                 368
# Vegetables                             368
# Pulses and products                    368
# Sugar and Confectionery                368
# Spices                                 368
# Non-alcoholic beverages                368
# Prepared meals, snacks, sweets etc.    365
# Food and beverages                     368
# Pan, tobacco and intoxicants           365
# Clothing                               365
# Footwear                               365
# Clothing and footwear                  365
# Housing                                249
# Fuel and light                         368
# ...

# %%
B=pd.notnull(df["Fruits"])
B
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 366    True
# 367    True
# 368    True
# 369    True
# 370    True
# Name: Fruits, Length: 371, dtype: bool

# %%
#number of unique values from each column in dataset
df.nunique()
# Out:
# Sector                                   3
# Year                                    11
# Month                                   14
# Cereals and products                   251
# Meat and fish                          289
# Egg                                    281
# Milk and products                      267
# Oils and fats                          255
# Fruits                                 279
# Vegetables                             311
# Pulses and products                    264
# Sugar and Confectionery                204
# Spices                                 280
# Non-alcoholic beverages                266
# Prepared meals, snacks, sweets etc.    305
# Food and beverages                     275
# Pan, tobacco and intoxicants           307
# Clothing                               303
# Footwear                               285
# Clothing and footwear                  301
# Housing                                117
# Fuel and light                         273
# ...

# %%
#total of unique values from dataset
df.nunique().sum()
# Out:
# 7429

# %%
#filling null values with given value in dataset
df.fillna(100)
# Out:
#           Sector  Year     Month  Cereals and products  Meat and fish    Egg  \
# 0          Rural  2013   January                 107.5          106.3  108.1
# 1          Urban  2013   January                 110.5          109.1  113.0
# 2    Rural+Urban  2013   January                 108.4          107.3  110.0
# 3          Rural  2013  February                 109.2          108.7  110.2
# 4          Urban  2013  February                 112.9          112.9  116.9
# ..           ...   ...       ...                   ...            ...    ...
# 366        Rural  2023     April                 173.3          206.9  167.9
# 367        Urban  2023     April                 174.8          213.7  172.4
# 368  Rural+Urban  2023     April                 173.8          209.3  169.6
# 369        Rural  2023       May                 173.2          211.5  171.0
# 370        Urban  2023       May                 174.7          219.4  176.7
#
# ...

# %%
#drop null values from dataset
df.dropna()
# Out:
#           Sector  Year     Month  Cereals and products  Meat and fish    Egg  \
# 1          Urban  2013   January                 110.5          109.1  113.0
# 2    Rural+Urban  2013   January                 108.4          107.3  110.0
# 4          Urban  2013  February                 112.9          112.9  116.9
# 5    Rural+Urban  2013  February                 110.4          110.2  112.8
# 7          Urban  2013     March                 113.9          111.4  113.2
# ..           ...   ...       ...                   ...            ...    ...
# 366        Rural  2023     April                 173.3          206.9  167.9
# 367        Urban  2023     April                 174.8          213.7  172.4
# 368  Rural+Urban  2023     April                 173.8          209.3  169.6
# 369        Rural  2023       May                 173.2          211.5  171.0
# 370        Urban  2023       May                 174.7          219.4  176.7
#
# ...

# %%
#drop the given columns which you dont want in further study  and inplace makes this changes permenently.
df.drop(["Miscellaneous","General index"],axis=1,inplace=True)

# %%
df.shape
# Out:
# (371, 28)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 366    False
# 367    False
# 368    False
# 369    False
# 370    False
# Length: 371, dtype: bool

# %%
#datatype of particular column
df["Cereals and products"].dtypes
# Out:
# dtype('float64')

# %%
#names of every column from dataset
df.columns
# Out:
# Index(['Sector', 'Year', 'Month', 'Cereals and products', 'Meat and fish',
#        'Egg', 'Milk and products', 'Oils and fats', 'Fruits', 'Vegetables',
#        'Pulses and products', 'Sugar and Confectionery', 'Spices',
#        'Non-alcoholic beverages', 'Prepared meals, snacks, sweets etc.',
#        'Food and beverages', 'Pan, tobacco and intoxicants', 'Clothing',
#        'Footwear', 'Clothing and footwear', 'Housing', 'Fuel and light',
#        'Household goods and services', 'Health', 'Transport and communication',
#        'Recreation and amusement', 'Education', 'Personal care and effects'],
#       dtype='object')

# %%
#renameing the column permenently
df.rename(columns={'Fruits':'Fruit'},inplace=True)

# %%
df.columns
# Out:
# Index(['Sector', 'Year', 'Month', 'Cereals and products', 'Meat and fish',
#        'Egg', 'Milk and products', 'Oils and fats', 'Fruit', 'Vegetables',
#        'Pulses and products', 'Sugar and Confectionery', 'Spices',
#        'Non-alcoholic beverages', 'Prepared meals, snacks, sweets etc.',
#        'Food and beverages', 'Pan, tobacco and intoxicants', 'Clothing',
#        'Footwear', 'Clothing and footwear', 'Housing', 'Fuel and light',
#        'Household goods and services', 'Health', 'Transport and communication',
#        'Recreation and amusement', 'Education', 'Personal care and effects'],
#       dtype='object')

# %% [markdown]
# STATISTICAL SUMMARY FOR STUDY

# %%
#statistical summery of whole dataset
df.describe()
# Out:
#               Year  Cereals and products  Meat and fish         Egg  \
# count   371.000000            368.000000     365.000000  368.000000
# mean   2017.695418            136.585326     156.105753  140.709511
# std       3.019120             14.893581      33.261467   22.490500
# min    2013.000000            107.500000     106.300000  102.700000
# 25%    2015.000000            124.175000     130.300000  122.075000
# 50%    2018.000000            135.850000     144.200000  135.500000
# 75%    2020.000000            146.325000     191.000000  161.650000
# max    2023.000000            174.800000     223.400000  197.000000
#
#        Milk and products  Oils and fats       Fruit  Vegetables  \
# count         368.000000     368.000000  368.000000  368.000000
# mean          140.218750     132.023370  140.755707  155.737772
# std            18.264993      29.932206   17.316939   27.943353
# min           103.600000     101.100000  102.300000  101.400000
# ...

# %%
#statistical summary of particular columns
df[["Pan, tobacco and intoxicants","Clothing and footwear"]].describe()
# Out:
#        Pan, tobacco and intoxicants  Clothing and footwear
# count                    365.000000             365.000000
# mean                     155.260822             141.552329
# std                       29.549158              20.895164
# min                      105.100000             105.800000
# 25%                      131.000000             125.000000
# 50%                      155.100000             141.400000
# 75%                      186.100000             152.800000
# max                      204.200000             190.800000

# %%
df[["Meat and fish","Egg"]].describe()
# Out:
#        Meat and fish         Egg
# count     365.000000  368.000000
# mean      156.105753  140.709511
# std        33.261467   22.490500
# min       106.300000  102.700000
# 25%       130.300000  122.075000
# 50%       144.200000  135.500000
# 75%       191.000000  161.650000
# max       223.400000  197.000000

# %%
df[["Egg"]].describe()
# Out:
#               Egg
# count  368.000000
# mean   140.709511
# std     22.490500
# min    102.700000
# 25%    122.075000
# 50%    135.500000
# 75%    161.650000
# max    197.000000

# %% [markdown]
# THANK YOU!
